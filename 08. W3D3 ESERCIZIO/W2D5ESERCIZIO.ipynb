# %%
import os
import dotenv
import sqlalchemy
import pandas as pd

# Load environment variables from .env file
dotenv.load_dotenv(override=True, dotenv_path=".env")

# Get database credentials from environment variables
username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")

# Build the connection string
conn_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"

# Create SQLAlchemy engine
db_engine = sqlalchemy.create_engine(conn_string)

# Define the query
query = "SELECT * FROM dimproduct"

# Execute the query and load the result into a DataFrame
db = pd.read_sql(query, con=db_engine)
db = pd.DataFrame(db)
# Display the DataFrame
print(db)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# 2                    None                None        BB Ball Bearing
# 3                    None                None  Headset Ball Bearings
# 4                    None                None                  Blade
# ..                    ...                 ...                    ...
# 601                     G                None      ML Bottom Bracket
# 602                     G                None      HL Bottom Bracket
# 603                    LB                  CM     Road-750 Black, 44
# 604                    LB                  CM     Road-750 Black, 48
# 605                    LB                  CM     Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 0                                                                    NaN
# 1                                                                    NaN
# 2                                                                    NaN
# 3                                                                    NaN
# 4                                                                    NaN
# ..                         ...                         ...           ...
# 601         Eje de pedalier GM          Axe de pédalier ML         44.95
# 602         Eje de pedalier GA          Axe de pédalier HL         53.94
# 603  Carretera: 750, negra, 44  Vélo de route 750 noir, 44        343.65
# 604  Carretera: 750, negra, 48  Vélo de route 750 noir, 48        343.65
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                 ChineseDescription  \
# 0                    0  ...                               None
# 1                    0  ...                               None
# 2                    0  ...                               None
# 3                    0  ...                               None
# 4                    0  ...                               None
# ..                 ...  ...                                ...
# 601                  1  ...                      铝合金车圈；大直径脚蹬轴。
# 602                  1  ...                         铝合金车圈和空心轴。
# 603                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
# 604                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
# 605                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 601  فناجين من سبيكة الألومنيوم؛ ذات محور دوران كبي...
# 602             فناجين من سبيكة الألومنيوم ومحور أجوف.
# 603  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
# 604  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 601           כיסויים מסגסוגת אלומיניום; ציר רחב-קוטר.
# 602               כיסויים מסגסוגת אלומיניום וציר חלול.
# 603  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
# 604  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 601              ดุมอลูมิเนียมอัลลอยด์ แกนเพลาขนาดใหญ่
# 602                   ดุมอลูมิเนียมอัลลอยด์และเพลากลวง
# 603  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
# 604  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 601  Außenringe aus Aluminiumlegierung; Radachse mi...
# 602  Außenringe aus Aluminiumlegierung und hohle Ac...
# 603  Ein Erwachsenenrad für Einsteiger; bietet Komf...
# 604  Ein Erwachsenenrad für Einsteiger; bietet Komf...
# 605  Ein Erwachsenenrad für Einsteiger; bietet Komf...
#
#                                    JapaneseDescription  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 601                               アルミニウム合金カップ、大径スピンドル。
# 602                              アルミニウム合金カップとホロー アクスル。
# 603  エントリー レベルに対応する、クロスカントリーにも街への買い物にも快適な、大人の自転車。ハブ...
# 604  エントリー レベルに対応する、クロスカントリーにも街への買い物にも快適な、大人の自転車。ハブ...
# 605  エントリー レベルに対応する、クロスカントリーにも街への買い物にも快適な、大人の自転車。ハブ...
#
#                                     TurkishDescription  StartDate EndDate  \
# 0                                                 None 2003-07-01     NaT
# 1                                                 None 2003-07-01     NaT
# 2                                                 None 2003-07-01     NaT
# 3                                                 None 2003-07-01     NaT
# 4                                                 None 2003-07-01     NaT
# ..                                                 ...        ...     ...
# 601  Alüminyum alaşımı orta göbekler; geniş çaplı mil. 2013-07-01     NaT
# 602    Alüminyum alaşımı orta göbekler ve içi boş aks. 2013-07-01     NaT
# 603  "Başlangıç seviyesinde yetişkin bisikleti, kır... 2013-07-01     NaT
# 604  "Başlangıç seviyesinde yetişkin bisikleti, kır... 2013-07-01     NaT
# 605  "Başlangıç seviyesinde yetişkin bisikleti, kır... 2013-07-01     NaT
#
#       Status
# 0    Current
# 1    Current
# 2    Current
# 3    Current
# 4    Current
# ..       ...
# 601  Current
# 602  Current
# 603  Current
# 604  Current
# 605  Current
#
# [606 rows x 36 columns]

# %%
# 1 Esercizio 1/3 Estraiamo la tabella dimproduct dal database AdventureWorks,
# e valutiamo quanto segue: 
# • Quanti dati ci sono in totale? 
db.shape
# Out:
# (606, 36)

# %%
# • Quali sono i metadati? 
db.columns
# Out:
# Index(['ProductKey', 'ProductAlternateKey', 'ProductSubcategoryKey',
#        'WeightUnitMeasureCode', 'SizeUnitMeasureCode', 'EnglishProductName',
#        'SpanishProductName', 'FrenchProductName', 'StandardCost',
#        'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint',
#        'ListPrice', 'Size', 'SizeRange', 'Weight', 'DaysToManufacture',
#        'ProductLine', 'DealerPrice', 'Class', 'Style', 'ModelName',
#        'LargePhoto', 'EnglishDescription', 'FrenchDescription',
#        'ChineseDescription', 'ArabicDescription', 'HebrewDescription',
#        'ThaiDescription', 'GermanDescription', 'JapaneseDescription',
#        'TurkishDescription', 'StartDate', 'EndDate', 'Status'],
#       dtype='object')

# %%
# • Stampiamo il primo elemento 
db.head(5)
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
# 1           2             BA-8327                    NaN
# 2           3             BE-2349                    NaN
# 3           4             BE-2908                    NaN
# 4           5             BL-2036                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                  None                None        Adjustable Race
# 1                  None                None           Bearing Ball
# 2                  None                None        BB Ball Bearing
# 3                  None                None  Headset Ball Bearings
# 4                  None                None                  Blade
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
# 1                                                NaN                  0  ...
# 2                                                NaN                  0  ...
# 3                                                NaN                  0  ...
# 4                                                NaN                  0  ...
#
#   ChineseDescription  ArabicDescription  HebrewDescription  ThaiDescription  \
# 0               None               None               None             None
# 1               None               None               None             None
# 2               None               None               None             None
# 3               None               None               None             None
# 4               None               None               None             None
#
#   GermanDescription JapaneseDescription  TurkishDescription  StartDate  \
# 0              None                None                None 2003-07-01
# 1              None                None                None 2003-07-01
# 2              None                None                None 2003-07-01
# 3              None                None                None 2003-07-01
# 4              None                None                None 2003-07-01
#
#   EndDate   Status
# 0     NaT  Current
# 1     NaT  Current
# 2     NaT  Current
# 3     NaT  Current
# 4     NaT  Current
#
# [5 rows x 36 columns]

# %%
# • Stampiamo l'ultimo elemento 
db.tail(5)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  EnglishProductName  \
# 601                     G                None   ML Bottom Bracket
# 602                     G                None   HL Bottom Bracket
# 603                    LB                  CM  Road-750 Black, 44
# 604                    LB                  CM  Road-750 Black, 48
# 605                    LB                  CM  Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 601         Eje de pedalier GM          Axe de pédalier ML         44.95
# 602         Eje de pedalier GA          Axe de pédalier HL         53.94
# 603  Carretera: 750, negra, 44  Vélo de route 750 noir, 44        343.65
# 604  Carretera: 750, negra, 48  Vélo de route 750 noir, 48        343.65
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                 ChineseDescription  \
# 601                  1  ...                      铝合金车圈；大直径脚蹬轴。
# 602                  1  ...                         铝合金车圈和空心轴。
# 603                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
# 604                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
# 605                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 601  فناجين من سبيكة الألومنيوم؛ ذات محور دوران كبي...
# 602             فناجين من سبيكة الألومنيوم ومحور أجوف.
# 603  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
# 604  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 601           כיסויים מסגסוגת אלומיניום; ציר רחב-קוטר.
# 602               כיסויים מסגסוגת אלומיניום וציר חלול.
# 603  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
# 604  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 601              ดุมอลูมิเนียมอัลลอยด์ แกนเพลาขนาดใหญ่
# 602                   ดุมอลูมิเนียมอัลลอยด์และเพลากลวง
# 603  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
# 604  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# 601  Außenringe aus Aluminiumlegierung; Radachse mi...
# 602  Außenringe aus Aluminiumlegierung und hohle Ac...
# 603  Ein Erwachsenenrad für Einsteiger; bietet Komf...
# 604  Ein Erwachsenenrad für Einsteiger; bietet Komf...
# 605  Ein Erwachsenenrad für Einsteiger; bietet Komf...
#
#                                    JapaneseDescription  \
# 601                               アルミニウム合金カップ、大径スピンドル。
# 602                              アルミニウム合金カップとホロー アクスル。
# 603  エントリー レベルに対応する、クロスカントリーにも街への買い物にも快適な、大人の自転車。ハブ...
# 604  エントリー レベルに対応する、クロスカントリーにも街への買い物にも快適な、大人の自転車。ハブ...
# 605  エントリー レベルに対応する、クロスカントリーにも街への買い物にも快適な、大人の自転車。ハブ...
#
#                                     TurkishDescription  StartDate EndDate  \
# 601  Alüminyum alaşımı orta göbekler; geniş çaplı mil. 2013-07-01     NaT
# 602    Alüminyum alaşımı orta göbekler ve içi boş aks. 2013-07-01     NaT
# 603  "Başlangıç seviyesinde yetişkin bisikleti, kır... 2013-07-01     NaT
# 604  "Başlangıç seviyesinde yetişkin bisikleti, kır... 2013-07-01     NaT
# 605  "Başlangıç seviyesinde yetişkin bisikleti, kır... 2013-07-01     NaT
#
#       Status
# 601  Current
# 602  Current
# 603  Current
# 604  Current
# 605  Current
#
# [5 rows x 36 columns]

# %%
# • Riusciamo a stampare cinque elementi a caso? 
db.sample(5)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 211         212           HL-U509-R                   31.0
# 112         113             LJ-7161                    NaN
# 578         579          BK-T44U-54                    3.0
# 138         139             LN-9161                    NaN
# 354         355          BK-M68S-42                    1.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode       EnglishProductName  \
# 211                  None                None    Sport-100 Helmet, Red
# 112                  None                None      Thin-Jam Lock Nut 7
# 578                    LB                  CM    Touring-2000 Blue, 54
# 138                  None                None              Lock Nut 18
# 354                    LB                  CM  Mountain-200 Silver, 42
#
#              SpanishProductName                FrenchProductName  \
# 211  Casco deportivo: 100, rojo          Casque sport 100, rouge
# 112
# 578       Paseo: 2000, azul, 54  Vélo de randonnée 2000 bleu, 54
# 138
# 354  Montaña: 200, plateada, 42               VTT 200 argent, 42
#
#      StandardCost  FinishedGoodsFlag  ...  \
# 211         12.03                  1  ...
# 112           NaN                  0  ...
# 578        755.15                  1  ...
# 138           NaN                  0  ...
# 354       1265.62                  1  ...
#
#                                     ChineseDescription  \
# 211                                通用型透气良好且轻便，带有自合型帽沿。
# 112                                               None
# 578  豪华的定制车座，确保您全天舒适骑乘，重新设计过的行李架上有足够的空间可添加驮篮和车筐。此自行...
# 138                                               None
# 354  适用于环境恶劣的野外骑乘。可应对各种比赛的完美赛车。使用与 Mountain-100 相同的...
#
#                                      ArabicDescription  \
# 211  ملائمة بشكل عام، وجيدة التهوية، وخفيفة الوزن ب...
# 112                                               None
# 578  إن مقعد الدراجة المخصص المصنوع من نسيج البلش ي...
# 138                                               None
# 354  لقيادة المحترفين في المناطق الريفية. دراجة مُث...
#
#                                      HebrewDescription  \
# 211  מידה אונברסלית, מאווררת היטב, קלת-משקל, עם מצח...
# 112                                               None
# 578  המושב המשובח והמותאם אישית מאפשר רכיבה לאורך ה...
# 138                                               None
# 354  לרכיבה רצינית בשטחים נידחים. מתאימים לכל רמה ש...
#
#                                        ThaiDescription  \
# 211       แว่นกันลมขนาดสากล ระบายอากาศได้ดี น้ำหนักเบา
# 112                                               None
# 578  เบาะนั่งหุ้มพิเศษช่วยให้คุณขี่อย่างสบายตลอดทั้...
# 138                                               None
# 354  สำหรับการขี่ในเส้นทางผจญภัย  เหมาะที่สุดสำหรับ...
#
#                                      GermanDescription  \
# 211  "Einheitsgröße, atmungsaktiv, leicht, aufsetzb...
# 112                                               None
# 578  "Der Polstersattel bietet Fahrkomfort für den ...
# 138                                               None
# 354  Mountainbike für Profis. Perfekt für alle Schw...
#
#                                    JapaneseDescription  \
# 211                軽量で通気性に優れたユニバーサル フィットのスナップ オン バイザー。
# 112                                               None
# 578  プラッシュ カスタム サドルは 1 日中乗っていたくなる快適さです。新設計の荷台には、パニエ...
# 138                                               None
# 354  バック カントリーまたは全レベルの競技用で、Mountain-100 と同じ HL フレーム...
#
#                                     TurkishDescription  StartDate    EndDate  \
# 211  "Her bisiklete kolayca takılabilen, aerodinami... 2011-07-01 2007-12-28
# 112                                               None 2003-07-01        NaT
# 578  "Özel yapım konforlu sele ile tüm gün bisiklet... 2013-07-01        NaT
# 138                                               None 2003-07-01        NaT
# 354  Gerçek arazi sürüşü. Tüm yarışma seviyeleri iç... 2013-07-01        NaT
#
#       Status
# 211     None
# 112  Current
# 578  Current
# 138  Current
# 354  Current
#
# [5 rows x 36 columns]

# %%
# • Quali sono i colori disponibili?
unique_colors = db['Color'].unique()
count = db["Color"].value_counts() 
print(unique_colors)
print(count)
# Out:
# ['NA' 'Black' 'Silver' 'Red' 'White' 'Blue' 'Multi' 'Yellow' 'Grey'
#  'Silver/Black']
# Color
# NA              254
# Black           133
# Red              63
# Silver           52
# Yellow           46
# Blue             28
# Multi            18
# Silver/Black      7
# White             4
# Grey              1
# Name: count, dtype: int64

# %%
# • In media quanto pesano i prodotti? 
average_weight = db['Weight'].mean()
print(f"Il peso medio dei prodotti è: {average_weight:.2f}")
# Out:
# Il peso medio dei prodotti è: 56.19

# %%
# • Quanto pesa il più leggero? 
weight_min= db['Weight'].min()
print(f"Il peso piu basso e' {weight_min}")
# Out:
# Il peso piu basso e' 2.12

# %%
# • Quanto pesa il più pesante? 
weight_max= db['Weight'].max()
print(f"Il peso piu alto e' {weight_max}")
# Out:
# Il peso piu alto e' 1050.0

# %%
# • Quanti prodotti pesano più di 100 Kg? 
filter = db['Weight']>100
heavy_prod = db[filter]
count_hp = heavy_prod.shape[0]
print(f"Il numero di prodotti che pesano più di 100 Kg è: {count_hp}")
# Out:
# Il numero di prodotti che pesano più di 100 Kg è: 28

# %%
# • Quanto costano in media i prodotti (colonna DealerPrice)? 

mediaprice = db['DealerPrice'].mean()

print(f"La media del costo e' {mediaprice:.2f}")
# Out:
# La media del costo e' 448.60

# %%
# • Se prendiamo un quarto di tutti i prodotti, in modo che siano i più costosi, quale sarà il loro range di prezzo?

dbsorted = db.sort_values(by='ListPrice', ascending=False)

db25 = dbsorted.head(int(len(dbsorted)*0.25))

min_25 = db25["ListPrice"].min()
max_25 = db25["ListPrice"].max()

print(f"Il range di prezzo per il 25% dei prodotti più costosi va da {min_25} a {max_25}")
# Out:
# Il range di prezzo per il 25% dei prodotti più costosi va da 742.35 a 3578.27

# %%
# • Qual è il prezzo medio per i prodotti di colore blu? 

filtro = db['Color'] == 'Blue'

prodblue = db[filtro]

avgprice = prodblue['ListPrice'].mean()


print(f"Il prezzo medio per i prodotti di colore blu è {avgprice:.2f}")
# Out:
# Il prezzo medio per i prodotti di colore blu è 860.10

# %%
# • Qual è il prezzo medio per i prodotti di colore rosso o nero? 
filtrorb = db['Color'].isin(['Red', "Black"])
prodblue = db[filtrorb]

avgprice = prodblue['ListPrice'].mean()


print(f"Il prezzo medio per i prodotti di colore blu è {avgprice:.2f}")
# Out:
# Il prezzo medio per i prodotti di colore blu è 917.08

# %%
# • Qual è il prezzo massimo per i prodotti di taglia 42 e peso oltre i 10 Kg? 
filter_db1 = (db['Size']== "42") & (db['Weight']>10)

filtered_d1 = db[filter_db1]
print(filtered_d1)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 344         345          BK-M82S-42                    1.0
# 348         349          BK-M82B-42                    1.0
# 353         354          BK-M68S-42                    1.0
# 354         355          BK-M68S-42                    1.0
# 359         360          BK-M68B-42                    1.0
# 360         361          BK-M68B-42                    1.0
# 384         385          BK-R64Y-42                    2.0
# 385         386          BK-R64Y-42                    2.0
# 580         581          BK-R79Y-42                    2.0
# 588         589          BK-M38S-42                    1.0
# 591         592          BK-M18S-42                    1.0
# 596         597          BK-M18B-42                    1.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode         EnglishProductName  \
# 344                    LB                  CM    Mountain-100 Silver, 42
# 348                    LB                  CM     Mountain-100 Black, 42
# 353                    LB                  CM    Mountain-200 Silver, 42
# 354                    LB                  CM    Mountain-200 Silver, 42
# 359                    LB                  CM     Mountain-200 Black, 42
# 360                    LB                  CM     Mountain-200 Black, 42
# 384                    LB                  CM      Road-550-W Yellow, 42
# 385                    LB                  CM      Road-550-W Yellow, 42
# 580                    LB                  CM      Road-350-W Yellow, 42
# 588                    LB                  CM  Mountain-400-W Silver, 42
# 591                    LB                  CM    Mountain-500 Silver, 42
# 596                    LB                  CM     Mountain-500 Black, 42
#
#                           SpanishProductName  \
# 344               Montaña: 100, plateada, 42
# 348                  Montaña: 100, negra, 42
# 353               Montaña: 200, plateada, 42
# 354               Montaña: 200, plateada, 42
# 359                  Montaña: 200, negra, 42
# 360                  Montaña: 200, negra, 42
# 384  Carretera: 550 para mujer, amarilla, 42
# 385  Carretera: 550 para mujer, amarilla, 42
# 580  Carretera: 350 para mujer, amarilla, 42
# 588    Montaña: 400 para mujer, plateada, 42
# 591               Montaña: 500, plateada, 42
# 596                  Montaña: 500, negra, 42
#
#                     FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 344                VTT 100 argent, 42       1912.15                  1  ...
# 348                  VTT 100 noir, 42       1898.09                  1  ...
# 353                VTT 200 argent, 42       1117.86                  1  ...
# 354                VTT 200 argent, 42       1265.62                  1  ...
# 359                  VTT 200 noir, 42       1105.81                  1  ...
# 360                  VTT 200 noir, 42       1251.98                  1  ...
# 384  Vélo de route 550 -W - jaune, 42        605.65                  1  ...
# 385  Vélo de route 550 -W - jaune, 42        713.08                  1  ...
# 580  Vélo de route 350 -W - jaune, 42       1082.51                  1  ...
# 588             VTT 400 -W argent, 42        419.78                  1  ...
# 591                VTT 500 argent, 42        308.22                  1  ...
# 596                  VTT 500 noir, 42        294.58                  1  ...
#
#                                     ChineseDescription  \
# 344  高档竞赛山地车。性能得到进一步增强，包括创新的 HL 车架、极其平稳的前悬架以及适用于所有地...
# 348  高档竞赛山地车。性能得到进一步增强，包括创新的 HL 车架、极其平稳的前悬架以及适用于所有地...
# 353  适用于环境恶劣的野外骑乘。可应对各种比赛的完美赛车。使用与 Mountain-100 相同的...
# 354  适用于环境恶劣的野外骑乘。可应对各种比赛的完美赛车。使用与 Mountain-100 相同的...
# 359  适用于环境恶劣的野外骑乘。可应对各种比赛的完美赛车。使用与 Mountain-100 相同的...
# 360  适用于环境恶劣的野外骑乘。可应对各种比赛的完美赛车。使用与 Mountain-100 相同的...
# 384  使用的技术与我们所有的公路系列自行车完全相同，但车架尺寸专为女士设计。完美的全能自行车，可作...
# 385  使用的技术与我们所有的公路系列自行车完全相同，但车架尺寸专为女士设计。完美的全能自行车，可作...
# 580  此自行车专为女士设计，造型清丽且符合空气动力学，您可参加越野训练、比赛或与亲朋好友共享悠闲生...
# 588                  此自行车具有优越的性价比。它灵敏且易于操控，越野骑乘也可轻松胜任。
# 591     适合所有类型的使用，不论是公路骑乘还是越野。不论预算多少，均可称心如意。变速平稳，骑乘舒适。
# 596     适合所有类型的使用，不论是公路骑乘还是越野。不论预算多少，均可称心如意。变速平稳，骑乘舒适。
#
#                                      ArabicDescription  \
# 344  دراجة سباقات مخصصة للقيادة في الجبال من أعلى ط...
# 348  دراجة سباقات مخصصة للقيادة في الجبال من أعلى ط...
# 353  لقيادة المحترفين في المناطق الريفية. دراجة مُث...
# 354  لقيادة المحترفين في المناطق الريفية. دراجة مُث...
# 359  لقيادة المحترفين في المناطق الريفية. دراجة مُث...
# 360  لقيادة المحترفين في المناطق الريفية. دراجة مُث...
# 384  ولها نفس التقنية المتوفرة في جميع دراجات سلسلة...
# 385  ولها نفس التقنية المتوفرة في جميع دراجات سلسلة...
# 580  يمكنكِ باستخدام هذه الدراجة الأنيقة التي تتميز...
# 588  توفر هذه الدراجة مستوى عاليًا من الأداء في حدو...
# 591  ملائمة لأي نوع من أنواع القيادة، سواءً على الط...
# 596  ملائمة لأي نوع من أنواع القيادة، سواءً على الط...
#
#                                      HebrewDescription  \
# 344  אופני הרים תחרותיים מהשורה הראשונה. אפשרויות ל...
# 348  אופני הרים תחרותיים מהשורה הראשונה. אפשרויות ל...
# 353  לרכיבה רצינית בשטחים נידחים. מתאימים לכל רמה ש...
# 354  לרכיבה רצינית בשטחים נידחים. מתאימים לכל רמה ש...
# 359  לרכיבה רצינית בשטחים נידחים. מתאימים לכל רמה ש...
# 360  לרכיבה רצינית בשטחים נידחים. מתאימים לכל רמה ש...
# 384  טכנולוגיה זהה לזו המצוי באופני סדרת "כביש" שלנ...
# 385  טכנולוגיה זהה לזו המצוי באופני סדרת "כביש" שלנ...
# 580  חציית שטחים, תחרות או סתם בילוי חברתי על אופני...
# 588  אופניים אלה מספקים רמת ביצועים גבוהה במחיר סבי...
# 591  מתאימים לכל סוג רכיבה, בדרכים סלולות ובשבילים ...
# 596  מתאימים לכל סוג רכיבה, בדרכים סלולות ובשבילים ...
#
#                                        ThaiDescription  \
# 344  สุดยอดจักรยานภูเขาสำหรับการแข่งขัน สมบูรณ์แบบด...
# 348  สุดยอดจักรยานภูเขาสำหรับการแข่งขัน สมบูรณ์แบบด...
# 353  สำหรับการขี่ในเส้นทางผจญภัย  เหมาะที่สุดสำหรับ...
# 354  สำหรับการขี่ในเส้นทางผจญภัย  เหมาะที่สุดสำหรับ...
# 359  สำหรับการขี่ในเส้นทางผจญภัย  เหมาะที่สุดสำหรับ...
# 360  สำหรับการขี่ในเส้นทางผจญภัย  เหมาะที่สุดสำหรับ...
# 384  เทคโนโลยีเดียวกับจักรยานรุ่น Road ทั้งหมด แต่ใ...
# 385  เทคโนโลยีเดียวกับจักรยานรุ่น Road ทั้งหมด แต่ใ...
# 580  ออกกำลัง แข่งขัน หรือสนุกสนานไปบนจักรยานคันเก๋...
# 588  จักรยานรุ่นนี้มีประสิทธิภาพสูง ในราคาประหยัด  ...
# 591  เหมาะสำหรับการขี่ทุกประเภท ทั้งบนถนนและแบบออฟโ...
# 596  เหมาะสำหรับการขี่ทุกประเภท ทั้งบนถนนและแบบออฟโ...
#
#                                      GermanDescription  \
# 344  "Top-Mountainbike für Profis. Mit innovativem ...
# 348  "Top-Mountainbike für Profis. Mit innovativem ...
# 353  Mountainbike für Profis. Perfekt für alle Schw...
# 354  Mountainbike für Profis. Perfekt für alle Schw...
# 359  Mountainbike für Profis. Perfekt für alle Schw...
# 360  Mountainbike für Profis. Perfekt für alle Schw...
# 384  Dieselbe Technologie wie bei allen Rädern unse...
# 385  Dieselbe Technologie wie bei allen Rädern unse...
# 580  "Ein schlankes, aerodynamisches Fahrrad für di...
# 588  Dieses Fahrrad bietet ein erstklassiges Preis-...
# 591  Geeignet für Straße und Gelände. Für jedes Bud...
# 596  Geeignet für Straße und Gelände. Für jedes Bud...
#
#                                    JapaneseDescription  \
# 344  最高級の競技用マウンテン バイクです。性能強化オプションとしては、革新的な HL フレーム、...
# 348  最高級の競技用マウンテン バイクです。性能強化オプションとしては、革新的な HL フレーム、...
# 353  バック カントリーまたは全レベルの競技用で、Mountain-100 と同じ HL フレーム...
# 354  バック カントリーまたは全レベルの競技用で、Mountain-100 と同じ HL フレーム...
# 359  バック カントリーまたは全レベルの競技用で、Mountain-100 と同じ HL フレーム...
# 360  バック カントリーまたは全レベルの競技用で、Mountain-100 と同じ HL フレーム...
# 384  ロード シリーズの自転車と同じ技術を使用した女性用サイズのフレームで、ロードにも競技にも適し...
# 385  ロード シリーズの自転車と同じ技術を使用した女性用サイズのフレームで、ロードにも競技にも適し...
# 580  空気力学に基づいて設計された優美な女性用自転車で、クロス トレーニングや競技にも、街乗りにも...
# 588  この自転車は予算内で高性能を提供します。応答性と操作性に優れ、オフロードでもゆったりした気分...
# 591    オンロードにもオフロードにも対応しながら、予算を選ばず、スムーズなシフトで快適な乗り心地です。
# 596    オンロードにもオフロードにも対応しながら、予算を選ばず、スムーズなシフトで快適な乗り心地です。
#
#                                     TurkishDescription  StartDate    EndDate  \
# 344  "En üst model rekabetçi dağ bisikleti. Perform... 2011-07-01 2007-12-28
# 348  "En üst model rekabetçi dağ bisikleti. Perform... 2011-07-01 2007-12-28
# 353  Gerçek arazi sürüşü. Tüm yarışma seviyeleri iç... 2012-07-01 2008-12-27
# 354  Gerçek arazi sürüşü. Tüm yarışma seviyeleri iç... 2013-07-01        NaT
# 359  Gerçek arazi sürüşü. Tüm yarışma seviyeleri iç... 2012-07-01 2008-12-27
# 360  Gerçek arazi sürüşü. Tüm yarışma seviyeleri iç... 2013-07-01        NaT
# 384  "Yol serisi bisikletlerimizle aynı teknoloji, ... 2012-07-01 2008-12-27
# 385  "Yol serisi bisikletlerimizle aynı teknoloji, ... 2013-07-01        NaT
# 580  "Kadınlar için tasarlanan bu şık ve aerodinami... 2013-07-01        NaT
# 588  "Bu bisiklet hem hesaplıdır, hem de yüksek sev... 2013-07-01        NaT
# 591  Yolda veya arazide her tür sürüşe uygundur. He... 2013-07-01        NaT
# 596  Yolda veya arazide her tür sürüşe uygundur. He... 2013-07-01        NaT
#
#       Status
# 344     None
# 348     None
# 353     None
# 354  Current
# 359     None
# 360  Current
# 384     None
# 385  Current
# 580  Current
# 588  Current
# 591  Current
# 596  Current
#
# [12 rows x 36 columns]

# %%
# • Qual è il nome inglese e il costo di produzione (StandardCost) di tutti i prodotti di taglia 42, peso oltre i 10 Kg e colore argento? 
    
filtered= (db['Size']== "42") & (db['Weight']>10) & (db['Color']=="Silver")
dbfiltered_2 = db[filtered]
if not dbfiltered_2.empty:
    print(db[["EnglishProductName","StandardCost"]]) # Doppie parentesi per passare le colonne specifiche da stampare 
else:
    print("Nessun prodotto soddisfa i criteri.")
# Out:
#         EnglishProductName  StandardCost
# 0          Adjustable Race           NaN
# 1             Bearing Ball           NaN
# 2          BB Ball Bearing           NaN
# 3    Headset Ball Bearings           NaN
# 4                    Blade           NaN
# ..                     ...           ...
# 601      ML Bottom Bracket         44.95
# 602      HL Bottom Bracket         53.94
# 603     Road-750 Black, 44        343.65
# 604     Road-750 Black, 48        343.65
# 605     Road-750 Black, 52        343.65
#
# [606 rows x 2 columns]

# %%
# • Esaminiamo la differenza tra lo StandardCost e il DealerPrice degli ultimi 20 elementi del dataset: c'è un pattern? C'è qualche elemento che non lo segue?
last20 = db.tail(20)
last20.loc[:,"Differenza"] = last20['DealerPrice'] - last20['StandardCost']
#print(last20[['ProductKey', 'StandardCost', 'DealerPrice', 'Differenza']])
print(last20['Differenza'])
# Out:
# 586    41.914
# 587    41.914
# 588    41.914
# 589    41.914
# 590    30.774
# 591    30.774
# 592    30.774
# 593    30.774
# 594    30.774
# 595    29.414
# 596    29.414
# 597    29.414
# 598    29.414
# 599    29.414
# 600     8.424
# 601    15.794
# 602    18.954
# 603   -19.656
# 604   -19.656
# 605   -19.656
# Name: Differenza, dtype: float64
# C:\Users\samee\AppData\Local\Temp\ipykernel_50540\4013127983.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last20.loc[:,"Differenza"] = last20['DealerPrice'] - last20['StandardCost']

# %%
#import db amazon

import pandas as pd 
file_path = "G:/EPICODE/Appunti/File Python/07. W2D5 ESERCIZIO/amazon.csv"

dbpokemon = pd.read_csv(file_path)
dbpokemon = pd.DataFrame(dbpokemon)
print(dbpokemon.head(3))
# Out:
#                                           reviewText  Positive
# 0  This is a one of the best apps acording to a b...         1
# 1  This is a pretty good version of the game for ...         1
# 2  this is a really cool game. there are a bunch ...         1

# %%
# • Valutiamo la dimensione del dataset 
dbpokemon.shape
# Out:
# (20000, 2)

# %%
# • Visualizziamo dieci righe a caso; 
dbpokemon.sample(10)
# Out:
#                                               reviewText  Positive
# 14329  Finally a good drum app I've been looking ever...         1
# 18638  I enjoyed the flexibility and functionality th...         1
# 360    When you order a game online that you download...         1
# 13691  I downloaded this app to my Kindle Fire thinki...         0
# 18905  what more can be said download it play it if y...         1
# 7343   this is a dumb app. Buy a dream book of you be...         0
# 12054  I used to always turn my alarm off after a few...         1
# 14079  I saw my friend Alex playing it and I want it ...         1
# 13210  If you're trying to hide porn on your Kindle F...         0
# 3266   I love this app.  It isn't perfect, but it is ...         1

# %%
# • Osserviamo quali sono i nomi di colonna; 
dbpokemon.columns
# Out:
# Index(['reviewText', 'Positive'], dtype='object')

# %%
# • Il dataset è bilanciato, ovvero, il numero di recensioni positive è uguale a quello delle negative, oppure no?

filtropositive = dbpokemon["Positive"]==1
filteredpositive= dbpokemon[filtropositive]
filtronegative = dbpokemon["Positive"] == 0
filterednegative = dbpokemon[filtronegative]
num_positive = len(filteredpositive)
num_negative = len(filterednegative)
num_tot = num_positive+num_negative

positive = (num_positive/num_tot)*100
negative = (num_negative/num_tot)*100

print(f"Numero di recensioni positive: {num_positive} il rapporto sul totale e' {positive:.1f}%")
print(f"Numero di recensioni negative: {num_negative} il rapporto sul totale e' {negative:.1f}%")
# Out:
# Numero di recensioni positive: 15233 il rapporto sul totale e' 76.2%
# Numero di recensioni negative: 4767 il rapporto sul totale e' 23.8%

# %%
# Esercizio Il dataset diabetes.csv raccoglie persone con diabete o meno, e il valore di diverse variabili fisiologiche dei pazienti.
# • Osserviamone le dimensioni e un'anteprima di cinque righe; • Prendiamoci un po' di tempo per dare un'occhiata ai metadati delle colonne; 
# • Stampiamo dei descrittori statistici del dataset; • Selezioniamo i dati relativi a diverse fasce di età: <20, 20-30, 30-40, 40-50, >50; 
# • Qual è la media della pressione sanguigna diastolica per le diverse fasce di età? 6 • Qual è la media della pressione per ogni singolo anno di età?

file_pathdiabites = "G:/EPICODE/Appunti/File Python/07. W2D5 ESERCIZIO/diabetes.csv"

db_diabetes = pd.read_csv(file_pathdiabites)
db_diabetes = pd.DataFrame(db_diabetes)
print(db_diabetes.head(3))
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1

# %%
db_diabetes.shape
# Out:
# (768, 9)

# %%
db_diabetes.columns
# Out:
# Index(['Number of times pregnant',
#        'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#        'Diastolic blood pressure (mm Hg)', 'Triceps skin fold thickness (mm)',
#        '2-Hour serum insulin (mu U/ml)',
#        'Body mass index (weight in kg/(height in m)^2)',
#        'Diabetes pedigree function', 'Age (years)', 'Class variable'],
#       dtype='object')

# %%
db_diabetes.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# count                        768.000000                        768.000000
# mean                          69.105469                         20.536458
# std                           19.355807                         15.952218
# min                            0.000000                          0.000000
# 25%                           62.000000                          0.000000
# 50%                           72.000000                         23.000000
# 75%                           80.000000                         32.000000
# max                          122.000000                         99.000000
#
#        2-Hour serum insulin (mu U/ml)  \
# count                      768.000000
# mean                        79.799479
# std                        115.244002
# min                          0.000000
# 25%                          0.000000
# 50%                         30.500000
# 75%                        127.250000
# max                        846.000000
#
#        Body mass index (weight in kg/(height in m)^2)  \
# count                                      768.000000
# mean                                        31.992578
# std                                          7.884160
# min                                          0.000000
# 25%                                         27.300000
# 50%                                         32.000000
# 75%                                         36.600000
# max                                         67.100000
#
#        Diabetes pedigree function  Age (years)  Class variable
# count                  768.000000   768.000000      768.000000
# mean                     0.471876    33.240885        0.348958
# std                      0.331329    11.760232        0.476951
# min                      0.078000    21.000000        0.000000
# 25%                      0.243750    24.000000        0.000000
# 50%                      0.372500    29.000000        0.000000
# 75%                      0.626250    41.000000        1.000000
# max                      2.420000    81.000000        1.000000
